# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Recursion4_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sum of first n numbers using recursion (functional)

def sum(n):
  if (n == 0):
    return 0

  return n+sum(n-1)

# %%
sum(3)
# Out:
# 6
