# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/BasicMaths14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#armstrong number
def digits(n):
  n2 = n
  sum = 0
  while n2>0:
    digit = n2%10
    n2//=10
    sum += (digit**3)
  if sum == n:
    return True
  else:
    return False

# %%
digits(371)
# Out:
# True
