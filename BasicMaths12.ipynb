# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/BasicMaths12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#reverse of a number
def digits(n):
  num = 0
  while n>0:
    digit = n%10
    n//=10
    num = num*10 + digit
  return num

# %%
digits(40100)
# Out:
# 104
