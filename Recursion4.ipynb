# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Recursion4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sum of first N numbers using recursion
def func(i, sum):
  if i < 1:
    print(sum)
    return

  func(i-1, sum + i)

# %%
func(3,0)
# Out:
# 6
