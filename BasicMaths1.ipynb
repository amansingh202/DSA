# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/BasicMaths1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#brute force approach
def digits(n):
  count = 0
  while n>0:
    n//=10
    count+=1
  return count

# %%
digits(111)
# Out:
# 3

# %%
import math

# %%
#another approcah
def count(n):
  cnt = (int)(math.log10(n) + 1)
  return cnt

# %%
count(12345)
# Out:
# 5
