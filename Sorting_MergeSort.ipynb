# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Sorting_MergeSort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sorting
#Merge sort (divide and conquer)

# %%
def mergeSort(arr, low, high):
  if low == high:
    return
  mid = (low+high)//2
  mergeSort(arr, low, mid)
  mergeSort(arr, mid+1, high)
  merge(arr, low, mid, high)

  return arr

# %%
def merge(arr, low, mid, high):
  temp = []
  left = low
  right = mid+1
  while (left <=mid and right <= high):
    if arr[left] < arr[right]:
      temp.append(arr[left])
      left = left+1
    else:
      temp.append(arr[right])
      right = right+1


  #for the leftovers elements

  #left side array
  while (left<=mid):
    temp.append(arr[left])
    left = left+1
  #right side array
  while (right<=high):
    temp.append(arr[right])
    right = right+1

  for i in range(low, high+1):
    arr[i] = temp[i - low]

  return arr

# %%
array = [13,46,24,52,20,9,5]

# %%
low = 0

# %%
high = len(array)

# %%
mergeSort(array, low, high - 1)
# Out:
# [5, 9, 13, 20, 24, 46, 52]

# %%
# Out:
# [5, 9, 13, 20, 24, 46, 52]
