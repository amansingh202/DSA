# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/pattern16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def nForest(n):
  ascii_val = 65
  for i in range(n):

    for j in range(n-i):
      print(chr(ascii_val), end=' ')

    #spaces
    for j in range(i):
      print(' ',end=' ')

    print()
    ascii_val += 1

# %%
nForest(5)
# Out:
# A A A A A
# B B B B
# C C C
# D D
# E

# %%
for i in range(1):
  print(i)
# Out:
# 0
