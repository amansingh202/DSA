# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Recursion3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#printing from N to 1 using recursion
def printN1(n,i):
  if n<i:
    return
  print(n, end = ' ')
  printN1(n-1, i)

# %%
printN1(9,1)
# Out:
# 9 8 7 6 5 4 3 2 1
