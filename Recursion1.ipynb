# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Recursion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#printing name n times using recursion
def name(i, n):
  if i>n:
    return
  print("Aman")
  name(i+1, n)

# %%
name(1,7)
# Out:
# Aman
# Aman
# Aman
# Aman
# Aman
# Aman
# Aman
