# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/Recursion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#printing from 1 to N using recursion
def print1n(i, n):
  if i>n:
    return
  print(i, end = ' ')
  print1n(i+1, n)

# %%
print1n(1,9)
# Out:
# 1 2 3 4 5 6 7 8 9
