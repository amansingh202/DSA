# %% [markdown]
# <a href="https://colab.research.google.com/github/amansingh202/DSA/blob/main/BasicMaths13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#palindrome number
def digits(n):
  n2 = n
  num = 0
  while n2>0:
    digit = n2%10
    n2//=10
    num = num*10 + digit
  if num == n:
    return True
  else:
    return False

# %%
digits(10001)
# Out:
# True
